# %%
import pandas as pd

# %% [markdown]
# ## Creating result lists from matches

# %%
# Write matches and match phases file paths
matches_path = 'Matches_b4fd5f7f-2575-4911-99a3-2c464103b4561751246462448.xlsx'
match_phases_path = 'MatchPhases_b4fd5f7f-2575-4911-99a3-2c464103b4561751246434390.xlsx'

# Write output path
output_path = 'data/2025/JUNE_womens_l2_sw_results.csv'

# %%
match_list = pd.read_excel(matches_path)
match_phases = pd.read_excel(match_phases_path)
match_phases = match_phases[match_phases['Phase'] != '1st Half-Time']
home_results = match_phases['Home result'].tolist()
away_results = match_phases['Away result'].tolist()
match_list.insert(3, 'home_result', home_results)
match_list.insert(4, 'away_result', away_results)
match_list = match_list.loc[:, ['Match ID', 'home_result', 'away_result', 'Home team', 'Away team', 'Name', 'Match date (EDT)']]
match_list.to_csv(output_path, index=False)
match_list
# Out:
# /home/on9/.pyenv/versions/3.12.1/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/on9/.pyenv/versions/3.12.1/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Match ID  home_result  away_result  Home team  Away team  \
# 0   262608430            2            0     175398     183413
# 1   262608435            1            2     175398     175386
# 2   262608441            2            2     183412     183413
# 3   262608442            2            0     175386     183415
# 4   262608443            3            1     183423     175738
# 5   262608444            2            2     175329     175334
# 6   262608445            0            2     183413     183412
# 7   262608446            0            3     175329     175398
# 8   262608447            4            1     175738     175323
# 9   262608448            1            1     175334     175386
# 10  262608449            3            1     175398     175323
# 11  262608450            4            2     183415     183413
# 12  262608451            4            1     183412     183423
# 13  262608452            1            3     175329     175386
# 14  262608453            2            7     183415     183423
# 15  262608454            0            0     175398     175738
# 16  262608455            1            2     175334     183413
# 17  262608456            8            0     183412     175323
# 18  262608457            2            4     175329     175738
# 19  262608458            0            1     175334     183412
# 20  262608459            1            1     175398     183415
# 21  262608460            1            2     183413     183423
# 22  262608461            7            0     175386     175323
#
#                                   Name    Match date (EDT)
# 0   League2 Ontario (W) Southwest 2025 2025-06-04 20:00:00
# 1   League2 Ontario (W) Southwest 2025 2025-06-25 20:30:00
# 2   League2 Ontario (W) Southwest 2025 2025-06-01 16:00:00
# 3   League2 Ontario (W) Southwest 2025 2025-06-01 18:00:00
# 4   League2 Ontario (W) Southwest 2025 2025-06-04 19:00:00
# 5   League2 Ontario (W) Southwest 2025 2025-06-05 21:00:00
# 6   League2 Ontario (W) Southwest 2025 2025-06-08 17:00:00
# 7   League2 Ontario (W) Southwest 2025 2025-06-09 21:00:00
# 8   League2 Ontario (W) Southwest 2025 2025-06-09 21:00:00
# 9   League2 Ontario (W) Southwest 2025 2025-06-12 20:30:00
# 10  League2 Ontario (W) Southwest 2025 2025-06-13 20:00:00
# 11  League2 Ontario (W) Southwest 2025 2025-06-14 15:00:00
# 12  League2 Ontario (W) Southwest 2025 2025-06-15 16:00:00
# 13  League2 Ontario (W) Southwest 2025 2025-06-16 21:00:00
# 14  League2 Ontario (W) Southwest 2025 2025-06-19 20:00:00
# 15  League2 Ontario (W) Southwest 2025 2025-06-20 20:00:00
# 16  League2 Ontario (W) Southwest 2025 2025-06-21 20:00:00
# 17  League2 Ontario (W) Southwest 2025 2025-06-22 16:00:00
# 18  League2 Ontario (W) Southwest 2025 2025-06-23 21:00:00
# 19  League2 Ontario (W) Southwest 2025 2025-06-26 20:30:00
# 20  League2 Ontario (W) Southwest 2025 2025-06-28 20:00:00
# 21  League2 Ontario (W) Southwest 2025 2025-06-29 17:00:00
# 22  League2 Ontario (W) Southwest 2025 2025-06-29 13:00:00
